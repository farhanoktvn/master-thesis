# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import matplotlib.pyplot as plt
import numpy as np
import random
from keras.models import Model, Sequential
from tqdm import tqdm
from PIL import Image

DATA_DIR = "/Users/farhanoktavian/imperial/thesis/sandbox/dataset/raw"
METADATA_DIR = "/Users/farhanoktavian/imperial/thesis/sandbox/dataset/data.h5"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mi = "/Users/farhanoktavian/imperial/thesis/sandbox/regist_eval/dataset/registered_short/HS020/Run06/g_label.png"
si = "/Users/farhanoktavian/imperial/thesis/sandbox/regist_eval/dataset/registered_short/HS020/Run06/g_fine.png"

mi_img = cv2.imread(mi, cv2.IMREAD_GRAYSCALE)
si_img = cv2.imread(si, cv2.IMREAD_GRAYSCALE)

# create image, mi on the left, si on the right
img = np.zeros((mi_img.shape[0], mi_img.shape[1]), dtype=np.uint8)
img[:, :mi_img.shape[1]//2] = mi_img[:, :mi_img.shape[1]//2]
img[:, mi_img.shape[1]//2:] = si_img[:, si_img.shape[1]//2:]

# Take 600x600 in the middle
img = img[img.shape[0]//2-300:img.shape[0]//2+300, img.shape[1]//2-300:img.shape[1]//2+300]

fig, ax = plt.subplots(figsize=(20, 11))
ax.imshow(img, cmap='gray')
ax.axis('off')
plt.tight_layout()
plt.show()
